# %%
import pandas as pd

# %%
df = pd.read_json('population.json')

# %%
df.head()
# Out:
#                                                 data
# 0  {'ID State': '04000US39', 'State': 'Ohio', 'ID...
# 1  {'ID State': '04000US72', 'State': 'Puerto Ric...
# 2  {'ID State': '04000US01', 'State': 'Alabama', ...
# 3  {'ID State': '04000US55', 'State': 'Wisconsin'...
# 4  {'ID State': '04000US02', 'State': 'Alaska', '...

# %%
df['State'] = df.data.map(lambda i: i['State'])

# %%
df['Pop'] =  df.data.map(lambda i: i['Population'])

# %%
df['Year'] = df.data.map(lambda i: i['Year'])

# %%
df.head()
# Out:
#                                                 data        State       Pop  \
# 0  {'ID State': '04000US39', 'State': 'Ohio', 'ID...         Ohio  11689442
# 1  {'ID State': '04000US72', 'State': 'Puerto Ric...  Puerto Rico   3195153
# 2  {'ID State': '04000US01', 'State': 'Alabama', ...      Alabama   4887871
# 3  {'ID State': '04000US55', 'State': 'Wisconsin'...    Wisconsin   5813568
# 4  {'ID State': '04000US02', 'State': 'Alaska', '...       Alaska    737438
#
#    Year
# 0  2018
# 1  2018
# 2  2018
# 3  2018
# 4  2018

# %%
dfUSA = df[['State',"Pop","Year"]]

# %%
dfUSA
# Out:
#            State       Pop  Year
# 0           Ohio  11689442  2018
# 1    Puerto Rico   3195153  2018
# 2        Alabama   4887871  2018
# 3      Wisconsin   5813568  2018
# 4         Alaska    737438  2018
# ..           ...       ...   ...
# 307     Missouri   6044171  2013
# 308   New Jersey   8899339  2013
# 309        Texas  26448193  2013
# 310     Oklahoma   3850568  2013
# 311      Montana   1015165  2013
#
# [312 rows x 3 columns]

# %%
dfUSA.head()
# Out:
#          State       Pop  Year
# 0         Ohio  11689442  2018
# 1  Puerto Rico   3195153  2018
# 2      Alabama   4887871  2018
# 3    Wisconsin   5813568  2018
# 4       Alaska    737438  2018

# %%
dfUSA.State.head()
# Out:
# 0           Ohio
# 1    Puerto Rico
# 2        Alabama
# 3      Wisconsin
# 4         Alaska
# Name: State, dtype: object

# %%
# dfUSA.to_dict(orient="records")

# %%
new_df = dfUSA[dfUSA['Year'] == '2018']

# %%
new_df
# Out:
#                    State       Pop  Year
# 0                   Ohio  11689442  2018
# 1            Puerto Rico   3195153  2018
# 2                Alabama   4887871  2018
# 3              Wisconsin   5813568  2018
# 4                 Alaska    737438  2018
# 5          West Virginia   1805832  2018
# 6             Washington   7535591  2018
# 7                Arizona   7171646  2018
# 8               Virginia   8517685  2018
# 9               Arkansas   3013825  2018
# 10               Vermont    626299  2018
# 11                  Utah   3161105  2018
# 12            California  39557045  2018
# 13                 Texas  28701845  2018
# 14              Colorado   5695564  2018
# 15             Tennessee   6770010  2018
# 16          South Dakota    882235  2018
# 17           Connecticut   3572665  2018
# 18        South Carolina   5084127  2018
# 19              Delaware    967171  2018
# 20          Rhode Island   1057315  2018
# 21          Pennsylvania  12807060  2018
# ...

# %%
us_pop_2018 = '327200000'

# %%
new_df['pop/uspop'] = dfUSA['Pop'] / 327200000
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.head()
# Out:
#          State       Pop  Year  pop/uspop
# 0         Ohio  11689442  2018   0.035726
# 1  Puerto Rico   3195153  2018   0.009765
# 2      Alabama   4887871  2018   0.014938
# 3    Wisconsin   5813568  2018   0.017768
# 4       Alaska    737438  2018   0.002254

# %%
new_df['per_US'] = new_df['pop/uspop'] * 100
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
new_df.head()
# Out:
#          State       Pop  Year  pop/uspop    per_US
# 0         Ohio  11689442  2018   0.035726  3.572568
# 1  Puerto Rico   3195153  2018   0.009765  0.976514
# 2      Alabama   4887871  2018   0.014938  1.493848
# 3    Wisconsin   5813568  2018   0.017768  1.776763
# 4       Alaska    737438  2018   0.002254  0.225378

# %%
quartile_data = new_df[['State', 'Pop', 'Year', 'per_US']]

# %%
quartile_data.head()
# Out:
#          State       Pop  Year    per_US
# 0         Ohio  11689442  2018  3.572568
# 1  Puerto Rico   3195153  2018  0.976514
# 2      Alabama   4887871  2018  1.493848
# 3    Wisconsin   5813568  2018  1.776763
# 4       Alaska    737438  2018  0.225378

# %%
# the qcut
import numpy as np
import seaborn as sns

# %%
bin_labels = ['4th', '3rd', '2nd', '1st']

# %%
quartile_data['quantile'] = pd.qcut(quartile_data['per_US'], q=4 , labels=bin_labels)

# %%
quartile_data
# Out:
#                    State       Pop  Year     per_US quantile
# 0                   Ohio  11689442  2018   3.572568      1st
# 1            Puerto Rico   3195153  2018   0.976514      3rd
# 2                Alabama   4887871  2018   1.493848      2nd
# 3              Wisconsin   5813568  2018   1.776763      2nd
# 4                 Alaska    737438  2018   0.225378      4th
# 5          West Virginia   1805832  2018   0.551905      3rd
# 6             Washington   7535591  2018   2.303053      1st
# 7                Arizona   7171646  2018   2.191823      2nd
# 8               Virginia   8517685  2018   2.603204      1st
# 9               Arkansas   3013825  2018   0.921096      3rd
# 10               Vermont    626299  2018   0.191412      4th
# 11                  Utah   3161105  2018   0.966108      3rd
# 12            California  39557045  2018  12.089561      1st
# 13                 Texas  28701845  2018   8.771958      1st
# ...

# %%
quartile_data.to_dict(orient="records")
# Out:
# [{'State': 'Ohio',
#   'Pop': 11689442,
#   'Year': '2018',
#   'per_US': 3.572567848410758,
#   'quantile': '1st'},
#  {'State': 'Puerto Rico',
#   'Pop': 3195153,
#   'Year': '2018',
#   'per_US': 0.9765137530562348,
#   'quantile': '3rd'},
#  {'State': 'Alabama',
#   'Pop': 4887871,
#   'Year': '2018',
#   'per_US': 1.4938481051344743,
#   'quantile': '2nd'},
#  {'State': 'Wisconsin',
#   'Pop': 5813568,
#   'Year': '2018',
#   'per_US': 1.776762836185819,
#   'quantile': '2nd'},
#  {'State': 'Alaska',
#   'Pop': 737438,
#   'Year': '2018',
#   'per_US': 0.2253783618581907,
#   'quantile': '4th'},
#  {'State': 'West Virginia',
#   'Pop': 1805832,
#   'Year': '2018',
#   'per_US': 0.5519046454767725,
#   'quantile': '3rd'},
#  {'State': 'Washington',
#   'Pop': 7535591,
#   'Year': '2018',
#   'per_US': 2.3030534841075796,
#   'quantile': '1st'},
#  {'State': 'Arizona',
#   'Pop': 7171646,
#   'Year': '2018',
#   'per_US': 2.191823349633252,
#   'quantile': '2nd'},
# ...

# %%
quartile_data.to_json('quartileData.json', orient='records')

# %%
dfquartile_data = quartile_data.to_dict(orient='records')

# %%
dfquartile_data.to
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-100-747536df7526> in <module>
# ----> 1 dfquartile_data.to
#
# AttributeError: 'list' object has no attribute 'to'

# %% [markdown]
# Next Year

# %%
df_2017 = dfUSA[dfUSA['Year'] == '2017']
df_2017.head()
# Out:
#        State       Pop  Year
# 52   Arizona   7016270  2017
# 53   Georgia  10429379  2017
# 54     Texas  28304596  2017
# 55      Ohio  11658609  2017
# 56  Colorado   5607154  2017

# %%
df_2017['pop/uspop'] = dfUSA['Pop'] / 327200000
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2017['per_US'] = df_2017['pop/uspop'] * 100
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2017
# Out:
#                     State       Pop  Year  pop/uspop     per_US
# 52                Arizona   7016270  2017   0.021443   2.144337
# 53                Georgia  10429379  2017   0.031875   3.187463
# 54                  Texas  28304596  2017   0.086505   8.650549
# 55                   Ohio  11658609  2017   0.035631   3.563145
# 56               Colorado   5607154  2017   0.017137   1.713678
# 57           North Dakota    755393  2017   0.002309   0.230866
# 58                 Hawaii   1427538  2017   0.004363   0.436289
# 59              Wisconsin   5795483  2017   0.017712   1.771236
# 60             Washington   7405743  2017   0.022634   2.263369
# 61         North Carolina  10273419  2017   0.031398   3.139798
# 62              Tennessee   6715984  2017   0.020526   2.052562
# 63                  Idaho   1716943  2017   0.005247   0.524738
# 64                 Alaska    739795  2017   0.002261   0.226099
# 65               New York  19849399  2017   0.060664   6.066442
# ...

# %%
quartile_data_2017 = df_2017[['State', 'Pop', 'Year', 'per_US']]
quartile_data_2017.head()
# Out:
#        State       Pop  Year    per_US
# 52   Arizona   7016270  2017  2.144337
# 53   Georgia  10429379  2017  3.187463
# 54     Texas  28304596  2017  8.650549
# 55      Ohio  11658609  2017  3.563145
# 56  Colorado   5607154  2017  1.713678

# %%
bin_labels = ['4th', '3rd', '2nd', '1st']

# %%
quartile_data_2017['quantile'] = pd.qcut(quartile_data_2017['per_US'], q=4 , labels=bin_labels)
quartile_data_2017
# Out:
#                     State       Pop  Year     per_US quantile
# 52                Arizona   7016270  2017   2.144337      2nd
# 53                Georgia  10429379  2017   3.187463      1st
# 54                  Texas  28304596  2017   8.650549      1st
# 55                   Ohio  11658609  2017   3.563145      1st
# 56               Colorado   5607154  2017   1.713678      2nd
# 57           North Dakota    755393  2017   0.230866      4th
# 58                 Hawaii   1427538  2017   0.436289      4th
# 59              Wisconsin   5795483  2017   1.771236      2nd
# 60             Washington   7405743  2017   2.263369      1st
# 61         North Carolina  10273419  2017   3.139798      1st
# 62              Tennessee   6715984  2017   2.052562      2nd
# 63                  Idaho   1716943  2017   0.524738      4th
# 64                 Alaska    739795  2017   0.226099      4th
# 65               New York  19849399  2017   6.066442      1st
# ...

# %%
quartile_data_2017.to_json('quartileData2017.json', orient='records')

# %% [markdown]
# Next Year

# %%
df_2016 = dfUSA[dfUSA['Year'] == '2016']
df_2016.head()
# Out:
#            State      Pop  Year
# 104   New Mexico  2081015  2016
# 105     Maryland  6016447  2016
# 106  Puerto Rico  3411307  2016
# 107     Michigan  9928300  2016
# 108        Maine  1331479  2016

# %%
df_2016['pop/uspop'] = dfUSA['Pop'] / 327200000
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2016['per_US'] = df_2016['pop/uspop'] * 100
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2016
# Out:
#                     State       Pop  Year  pop/uspop     per_US
# 104            New Mexico   2081015  2016   0.006360   0.636007
# 105              Maryland   6016447  2016   0.018388   1.838767
# 106           Puerto Rico   3411307  2016   0.010426   1.042575
# 107              Michigan   9928300  2016   0.030343   3.034322
# 108                 Maine   1331479  2016   0.004069   0.406931
# 109               Alabama   4863300  2016   0.014863   1.486339
# 110             Minnesota   5519952  2016   0.016870   1.687027
# 111               Wyoming    585501  2016   0.001789   0.178943
# 112             Louisiana   4681666  2016   0.014308   1.430827
# 113           Mississippi   2988726  2016   0.009134   0.913425
# 114                Alaska    741894  2016   0.002267   0.226740
# 115              Missouri   6093000  2016   0.018622   1.862164
# 116              Kentucky   4436974  2016   0.013560   1.356043
# 117             Wisconsin   5778709  2016   0.017661   1.766109
# ...

# %%
quartile_data_2016 = df_2016[['State', 'Pop', 'Year', 'per_US']]
quartile_data_2016.head()
# Out:
#            State      Pop  Year    per_US
# 104   New Mexico  2081015  2016  0.636007
# 105     Maryland  6016447  2016  1.838767
# 106  Puerto Rico  3411307  2016  1.042575
# 107     Michigan  9928300  2016  3.034322
# 108        Maine  1331479  2016  0.406931

# %%
quartile_data_2016['quantile'] = pd.qcut(quartile_data_2016['per_US'], q=4 , labels=bin_labels)
quartile_data_2016
# Out:
#                     State       Pop  Year     per_US quantile
# 104            New Mexico   2081015  2016   0.636007      3rd
# 105              Maryland   6016447  2016   1.838767      2nd
# 106           Puerto Rico   3411307  2016   1.042575      3rd
# 107              Michigan   9928300  2016   3.034322      1st
# 108                 Maine   1331479  2016   0.406931      4th
# 109               Alabama   4863300  2016   1.486339      2nd
# 110             Minnesota   5519952  2016   1.687027      2nd
# 111               Wyoming    585501  2016   0.178943      4th
# 112             Louisiana   4681666  2016   1.430827      2nd
# 113           Mississippi   2988726  2016   0.913425      3rd
# 114                Alaska    741894  2016   0.226740      4th
# 115              Missouri   6093000  2016   1.862164      2nd
# 116              Kentucky   4436974  2016   1.356043      2nd
# 117             Wisconsin   5778709  2016   1.766109      2nd
# ...

# %%
quartile_data_2016.to_json('quartileData2016.json', orient='records')

# %% [markdown]
# Next Year

# %%
df_2015 = dfUSA[dfUSA['Year'] == '2015']
df_2015.head()
# Out:
#            State       Pop  Year
# 156     Kentucky   4425092  2015
# 157   New Mexico   2085109  2015
# 158      Alabama   4858979  2015
# 159  Puerto Rico   3474182  2015
# 160     Illinois  12859995  2015

# %%
df_2015['pop/uspop'] = dfUSA['Pop'] / 327200000
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2015['per_US'] = df_2015['pop/uspop'] * 100
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2015
# Out:
#                     State       Pop  Year  pop/uspop     per_US
# 156              Kentucky   4425092  2015   0.013524   1.352412
# 157            New Mexico   2085109  2015   0.006373   0.637258
# 158               Alabama   4858979  2015   0.014850   1.485018
# 159           Puerto Rico   3474182  2015   0.010618   1.061792
# 160              Illinois  12859995  2015   0.039303   3.930316
# 161               Montana   1032949  2015   0.003157   0.315693
# 162              New York  19795791  2015   0.060501   6.050058
# 163              Michigan   9922576  2015   0.030326   3.032572
# 164              Virginia   8382993  2015   0.025620   2.562039
# 165             Wisconsin   5771337  2015   0.017639   1.763856
# 166            California  39144818  2015   0.119636  11.963575
# 167        North Carolina  10042802  2015   0.030693   3.069316
# 168              Oklahoma   3911338  2015   0.011954   1.195397
# 169                 Idaho   1654930  2015   0.005058   0.505785
# ...

# %%
quartile_data_2015 = df_2015[['State', 'Pop', 'Year', 'per_US']]
quartile_data_2015.head()
# Out:
#            State       Pop  Year    per_US
# 156     Kentucky   4425092  2015  1.352412
# 157   New Mexico   2085109  2015  0.637258
# 158      Alabama   4858979  2015  1.485018
# 159  Puerto Rico   3474182  2015  1.061792
# 160     Illinois  12859995  2015  3.930316

# %%
quartile_data_2015['quantile'] = pd.qcut(quartile_data_2015['per_US'], q=4 , labels=bin_labels)
quartile_data_2015
# Out:
#                     State       Pop  Year     per_US quantile
# 156              Kentucky   4425092  2015   1.352412      2nd
# 157            New Mexico   2085109  2015   0.637258      3rd
# 158               Alabama   4858979  2015   1.485018      2nd
# 159           Puerto Rico   3474182  2015   1.061792      3rd
# 160              Illinois  12859995  2015   3.930316      1st
# 161               Montana   1032949  2015   0.315693      4th
# 162              New York  19795791  2015   6.050058      1st
# 163              Michigan   9922576  2015   3.032572      1st
# 164              Virginia   8382993  2015   2.562039      1st
# 165             Wisconsin   5771337  2015   1.763856      2nd
# 166            California  39144818  2015  11.963575      1st
# 167        North Carolina  10042802  2015   3.069316      1st
# 168              Oklahoma   3911338  2015   1.195397      3rd
# 169                 Idaho   1654930  2015   0.505785      4th
# ...

# %%
quartile_data_2015.to_json('quartileData2015.json', orient='records')

# %% [markdown]
# Last Year

# %%
df_2014 = dfUSA[dfUSA['Year'] == '2014']
df_2014.head()
# Out:
#                     State      Pop  Year
# 208            New Mexico  2085572  2014
# 209          South Dakota   853175  2014
# 210        South Carolina  4832482  2014
# 211             Tennessee  6549352  2014
# 212  District of Columbia   658893  2014

# %%
df_2014['pop/uspop'] = dfUSA['Pop'] / 327200000
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2014['per_US'] = df_2014['pop/uspop'] * 100
# Out:
# C:\Users\meagc\Anaconda\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
df_2014
# Out:
#                     State       Pop  Year  pop/uspop     per_US
# 208            New Mexico   2085572  2014   0.006374   0.637400
# 209          South Dakota    853175  2014   0.002608   0.260750
# 210        South Carolina   4832482  2014   0.014769   1.476920
# 211             Tennessee   6549352  2014   0.020016   2.001636
# 212  District of Columbia    658893  2014   0.002014   0.201373
# 213          Rhode Island   1055173  2014   0.003225   0.322486
# 214               Florida  19893297  2014   0.060799   6.079858
# 215           Connecticut   3596677  2014   0.010992   1.099229
# 216                 Texas  26956958  2014   0.082387   8.238679
# 217          Pennsylvania  12787209  2014   0.039081   3.908071
# 218                Oregon   3970239  2014   0.012134   1.213398
# 219               Georgia  10097343  2014   0.030860   3.085985
# 220         Massachusetts   6745408  2014   0.020616   2.061555
# 221                  Utah   2942902  2014   0.008994   0.899420
# ...

# %%
quartile_data_2014 = df_2014[['State', 'Pop', 'Year', 'per_US']]
quartile_data_2014.head()
# Out:
#                     State      Pop  Year    per_US
# 208            New Mexico  2085572  2014  0.637400
# 209          South Dakota   853175  2014  0.260750
# 210        South Carolina  4832482  2014  1.476920
# 211             Tennessee  6549352  2014  2.001636
# 212  District of Columbia   658893  2014  0.201373

# %%
quartile_data_2014['quantile'] = pd.qcut(quartile_data_2014['per_US'], q=4 , labels=bin_labels)
quartile_data_2014
# Out:
#                     State       Pop  Year     per_US quantile
# 208            New Mexico   2085572  2014   0.637400      3rd
# 209          South Dakota    853175  2014   0.260750      4th
# 210        South Carolina   4832482  2014   1.476920      2nd
# 211             Tennessee   6549352  2014   2.001636      2nd
# 212  District of Columbia    658893  2014   0.201373      4th
# 213          Rhode Island   1055173  2014   0.322486      4th
# 214               Florida  19893297  2014   6.079858      1st
# 215           Connecticut   3596677  2014   1.099229      3rd
# 216                 Texas  26956958  2014   8.238679      1st
# 217          Pennsylvania  12787209  2014   3.908071      1st
# 218                Oregon   3970239  2014   1.213398      3rd
# 219               Georgia  10097343  2014   3.085985      1st
# 220         Massachusetts   6745408  2014   2.061555      2nd
# 221                  Utah   2942902  2014   0.899420      3rd
# ...

# %%
quartile_data_2014.to_json('quartileData2014.json', orient='records')
